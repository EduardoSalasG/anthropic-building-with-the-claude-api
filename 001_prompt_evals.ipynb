# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages =[]
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
        json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses an AWS S3 bucket URI:\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket and key.\n    \n    Args:\n        uri (str): S3 URI in format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Find the first slash to separate bucket from key\n    slash_index = uri_without_prefix.find('/')\n    \n    if slash_index == -1:\n        # No key, only bucket\n        bucket = uri_without_prefix\n        key = \"\"\n    else:\n        bucket = uri_without_prefix[:slash_index]\n        key = uri_without_prefix[slash_index + 1:]\n    \n    if not bucket:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: URI with full path\n    result1 = parse_s3_uri('s3://my-bucket/path/to/file.txt')\n    print(f\"Test 1: {result1}\")\n    # Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \n    # Test 2: URI with only bucket\n    result2 = parse_s3_uri('s3://my-bucket/')\n    print(f\"Test 2: {result2}\")\n    # Output: {'bucket': 'my-bucket', 'key': ''}\n    \n    # Test 3: URI with bucket only (no trailing slash)\n    result3 = parse_s3_uri('s3://my-bucket')\n    print(f\"Test 3: {result3}\")\n    # Output: {'bucket': 'my-bucket', 'key': ''}\n    \n    # Test 4: Complex path\n    result4 = parse_s3_uri('s3://my-bucket/folder/subfolder/file-with-dashes_123.txt')\n    print(f\"Test 4: {result4}\")\n    # Output: {'bucket': 'my-bucket', 'key': 'folder/subfolder/file-with-dashes_123.txt'}\n    \n    # Test 5: Error handling\n    try:\n        parse_s3_uri('https://my-bucket/path/to/file.txt')\n    except ValueError as e:\n        print(f\"Test 5 (Expected Error): {e}\")\n    \n    try:\n        parse_s3_uri('s3:///')\n    except ValueError as e:\n        print(f\"Test 6 (Expected Error): {e}\")\n```\n\n**Output:**\n```\nTest 1: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\nTest 2: {'bucket': 'my-bucket', 'key': ''}\nTest 3: {'bucket': 'my-bucket', 'key': ''}\nTest 4: {'bucket': 'my-bucket', 'key': 'folder/subfolder/file-with-dashes_123.txt'}\nTest 5 (Expected Error): URI must start with 's3://'\nTest 6 (Expected Error): Bucket name cannot be empty\n```\n\n## Alternative: Using Regular Expressions\n\nIf you prefer a more concise approach using regex:\n\n```python\nimport re\n\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI using regex.\n    \n    Args:\n        uri (str): S3 URI in format",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with keys 'bucket' and 'key'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object representing an IAM policy for read-only S3 access:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Explanation\n\n**Statement 1 - S3ReadOnlyAccess:**\n- `s3:GetObject` - Allows reading objects from the bucket\n- `s3:GetObjectVersion` - Allows reading specific versions of objects\n- `Resource`: `arn:aws:s3:::my-data-bucket/*` - Applies to all objects in the bucket\n\n**Statement 2 - S3ListBucket:**\n- `s3:ListBucket` - Allows listing bucket contents\n- `s3:GetBucketVersioning` - Allows checking versioning status\n- `Resource`: `arn:aws:s3:::my-data-bucket` - Applies to the bucket itself\n\nThis policy grants read-only access without allowing modifications, deletions, or bucket configuration changes.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the solution:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix (required for all EC2 instance IDs) |\n| `[0-9a-f]` | Character class matching hex digits (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid Matches \u2713\n- `i-0abcd1234efgh5678`\n- `i-1234567890abcdef0`\n- `i-aaaaaaaaaaaaaaaaa`\n\n### Invalid (No Match) \u2717\n- `i-0abcd1234efgh567` (only 16 hex chars)\n- `i-0abcd1234efgh56789` (18 hex chars)\n- `0abcd1234efgh5678` (missing `i-` prefix)\n- `i-0abcd1234efgh567G` (contains 'G', not valid hex)\n\n## Implementation Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nconsole.log(pattern.test('i-0abcd1234efgh5678')); // true\n```\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nre.match(pattern, 'i-0abcd1234efgh5678')  # Match object (True)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: 'i-' followed by 17 hexadecimal characters, e.g., 'i-0abcd1234efgh5678')."
#     },
#     "score": 10
#   }
# ]
