# %%
# Install dependencies

# %pip install anthropic python-dotenv
# Out:
# Collecting anthropic
#   Downloading anthropic-0.109.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting anyio<5,>=3.5.0 (from anthropic)
#   Downloading anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from anthropic)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic)
#   Downloading jiter-0.15.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from anthropic)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\salas\documents\anthropic-courses\building-with-the-claude-api\.venv\lib\site-packages (from anthropic) (4.15.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->anthropic)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi (from httpx<1,>=0.25.0->anthropic)
#   Downloading certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->anthropic)
#   Downloading pydantic_core-2.46.4-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->anthropic)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading anthropic-0.109.2-py3-none-any.whl (923 kB)
#    ---------------------------------------- 0.0/923.8 kB ? eta -:--:--
#    ---------------------------------------- 923.8/923.8 kB 5.7 MB/s eta 0:00:00
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.15.0-cp313-cp313-win_amd64.whl (196 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.0 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.5.20-py3-none-any.whl (134 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-inspection, sniffio, python-dotenv, pydantic-core, jiter, idna, h11, docstring-parser, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, anthropic
# Successfully installed annotated-types-0.7.0 anthropic-0.109.2 anyio-4.14.0 certifi-2026.5.20 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jiter-0.15.0 pydantic-2.13.4 pydantic-core-2.46.4 python-dotenv-1.2.2 sniffio-1.3.1 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
        user_message = {"role": "user", "content": text}
        messages.append(user_message)

def add_assistant_message(messages, text):
        assistant_message = {"role": "assistant", "content": text}
        messages.append(assistant_message)

def chat(messages):
    # Make a request
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

while 1==1:
    print("Write your question")
    user_message = input("> ")
    print("> ", user_message)
    print("--")

    # Add in the initial user question of "Define quatum computing in one sentence"
    add_user_message(messages, user_message)

    # Pass the list of messages into "chat" to get an answer
    answer = chat(messages)
    print(answer)
    print("--")

    # Take the answer and add it as an assistant message into our list
    add_assistant_message(messages, answer)
# Out:
# Write your question
# >  How much is 5+5
# --
# 5 + 5 = **10**
# --
# Write your question
# >
# --
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[17], line 14
#      10     # Add in the initial user question of "Define quatum computing in one sentence"
#      11     add_user_message(messages, user_message)
#      12
#      13     # Pass the list of messages into "chat" to get an answer
# ---> 14     answer = chat(messages)
#      15     print(answer)
#      16     print("--")
#      17
#
# Cell In[11], line 11, in chat(messages)
#       9 def chat(messages):
#      10     # Make a request
# ---> 11     message = client.messages.create(
#      12         model=model,
#      13         max_tokens=1000,
#      14         messages=messages,
#
# File ~/Documents/Anthropic/anthropic-building-with-the-claude-api/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Documents/Anthropic/anthropic-building-with-the-claude-api/.venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:1009, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1002 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1003     warnings.warn(
#    1004         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1005         UserWarning,
#    1006         stacklevel=3,
#    1007     )
# -> 1009 return self._post(
#    1010     "/v1/messages",
#    1011     body=maybe_transform(
#    1012         {
#    1013             "max_tokens": max_tokens,
#    1014             "messages": messages,
#    1015             "model": model,
#    1016             "cache_control": cache_control,
#    1017             "container": container,
#    1018             "inference_geo": inference_geo,
#    1019             "metadata": metadata,
#    1020             "output_config": output_config,
#    1021             "service_tier": service_tier,
#    1022             "stop_sequences": stop_sequences,
#    1023             "stream": stream,
#    1024             "system": system,
#    1025             "temperature": temperature,
#    1026             "thinking": thinking,
#    1027             "tool_choice": tool_choice,
#    1028             "tools": tools,
#    1029             "top_k": top_k,
#    1030             "top_p": top_p,
#    1031         },
#    1032         message_create_params.MessageCreateParamsStreaming
#    1033         if stream
#    1034         else message_create_params.MessageCreateParamsNonStreaming,
#    1035     ),
#    1036     options=make_request_options(
#    1037         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1038     ),
#    1039     cast_to=Message,
#    1040     stream=stream or False,
#    1041     stream_cls=Stream[RawMessageStreamEvent],
#    1042 )
#
# File ~/Documents/Anthropic/anthropic-building-with-the-claude-api/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1535, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1526     warnings.warn(
#    1527         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1528         "Please pass raw bytes via the `content` parameter instead.",
#    1529         DeprecationWarning,
#    1530         stacklevel=2,
#    1531     )
#    1532 opts = FinalRequestOptions.construct(
#    1533     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1534 )
# -> 1535 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Anthropic/anthropic-building-with-the-claude-api/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1191     if not response.is_closed:
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.2: user messages must have non-empty content'}, 'request_id': 'req_011Cc9Y7QSRDBuysqr6bet6j'}
